# %% [markdown]
# <a href="https://colab.research.google.com/github/a-forty-two/EY_batch11_3Mar/blob/main/5Mar_002_Calculating_Weights_and_bias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Welcome back!

# %% [markdown]
# In this lab, we will observe how weights and bias are trained over epochs.

# %% [markdown]
# Let's begin with importing the libraries and read the dataset. We will also break the dataset into features and labels.

# %%
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
#IGNORE ANY WARNINGS THAT MAY APPEAR ON THIS CELL

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('https://raw.githubusercontent.com/a-forty-two/EY_batch11_3Mar/refs/heads/main/data.csv')

# %%
x = data[['radius_mean', 'symmetry_mean']]
y = data[['diagnosis']]

# %% [markdown]
# We are using the same dataset as in the last lab- view the inputs and labels.

# %%
x.head()
# Out:
#    radius_mean  symmetry_mean
# 0        17.99         0.2419
# 1        20.57         0.1812
# 2        19.69         0.2069
# 3        11.42         0.2597
# 4        20.29         0.1809

# %%
x['radius_mean'].min(),x['radius_mean'].max(),x['symmetry_mean'].min(),x['symmetry_mean'].max()
# Out:
# (6.981, 28.11, 0.106, 0.304)

# %%
# Normalization

# min/max or absolute scaling -> 0 to 1 -> (data- min)/ (max - min)

# z-score or standard scaling -> -inf to +inf-> -3 to +3; smaller than -3 or greater + 3 is called outlier
#           z-score = (data - mean) / std

# tanh -> hyperbolic tangent -> -1 to +1

# sigmoid -> logloss -> 0 to 1 -> but probabilistic/logarithmic

# %%
y.head()
# Out:
#   diagnosis
# 0         M
# 1         M
# 2         M
# 3         M
# 4         M

# %% [markdown]
# Using the same process as the last lab, we will normalize the inputs, and encode the labels.

# %%
x.describe().T
# Out:
#                count       mean       std    min      25%      50%      75%  \
# radius_mean    569.0  14.127292  3.524049  6.981  11.7000  13.3700  15.7800
# symmetry_mean  569.0   0.181162  0.027414  0.106   0.1619   0.1792   0.1957
#
#                   max
# radius_mean    28.110
# symmetry_mean   0.304

# %%
#Normalize Input
stats = x.describe().T
mu, sigma = stats['mean'], stats['std']

# %%
x_norm = (x-mu)/sigma

# %%
x_norm
# Out:
#      radius_mean  symmetry_mean
# 0       1.096100       2.215566
# 1       1.828212       0.001391
# 2       1.578499       0.938859
# 3      -0.768233       2.864862
# 4       1.748758      -0.009552
# ..           ...            ...
# 564     2.109139      -0.312314
# 565     1.703356      -0.217473
# 566     0.701667      -0.808406
# 567     1.836725       2.135315
# 568    -1.806811      -0.819349
#
# [569 rows x 2 columns]

# %%
rule = lambda val: 1 if val=='M' else 0

# %%
y=y['diagnosis'].apply(rule)

# %%
y.tail()
# Out:
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, dtype: int64

# %% [markdown]
# Now we will proceed to splitting the data. No changes so far-

# %%
HP_epochs = 1000
HP_batch_size = 16
HP_lr = 0.001

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x_norm,y,random_state=42)

# %% [markdown]
# Our dataset is small. But for big data, or larger datasets, we can use TensorFlow's Dataset API.
# <br/>
# We additionally shuffle the dataset to provide randomness.
#
# Because we are going to simulate the training process over epochs, we will also repeat our dataset.
#
# We will also divide our data into fixed size batches.

# %%
celldata = tf.data.Dataset.from_tensor_slices((xtrain,ytrain))
celldata = celldata.shuffle(100).repeat(HP_epochs).batch(HP_batch_size)

# %% [markdown]
# This is the simplest way to create a dataset.
#
# dataset = tf.data.Dataset.from_tensor_slices(any_tensor_or_numpy_array_or_pandas_dataset)

# %% [markdown]
# Now we will place an iterator on top of our dataset to loop into the actual data.

# %%
itr = celldata.__iter__()
#IGNORE ANY WARNINGS THAT MAY APPEAR ON THIS CELL

# %% [markdown]
# Now, we will initialize our weights and bias. We are initializing the weights with random numbers, normally distributed from the mean 0, with a standard deviation of 0.5.

# %%
# we have only 2 features and 1 label
# One weight for each feature
w = tf.random.normal( ( 2 , 1 ), mean = 0, stddev =0.5,dtype=tf.dtypes.double )
# One bias for every output
# our only output is the label prediction on 1 layer
b = 0

# %% [markdown]
# Have a look at the initial weights

# %%
print(w)
# Out:
# tf.Tensor(
# [[-0.45412276]
#  [ 0.04448633]], shape=(2, 1), dtype=float64)

# %%
# define an empty array to store all the errors
# errors will be generated from each training simulation
err = []

# %% [markdown]
# Let's define a dummy classifier to encode our predictions into 1 and 0

# %%
def myclassifier(vals):
  res = []
  rule = lambda r: 1.0 if r>=0.5 else 0.0
  for val in vals:
    res.append(rule(val))
  return res

# %% [markdown]
# And let's begin the training simulation!

# %% [markdown]
# TensorFlow functions to observe
#
#
# *   tensordot - returns dot product
# *   cast - datatype casting on tensors
# *   reduce_mean - mean of TensorFlow datasets

# %%
itrs_per_epoch = int(len(xtrain)/HP_batch_size)
# Each iteration represents 1 epoch
for i in range(HP_epochs):
  per_iter_err = []
  for j in range(itrs_per_epoch):
    # get data and labels in fixed batch sizes
    data, labels = itr.get_next()

    # simplest representation of ML
    # y = mx + c
    y = tf.tensordot(data, w, axes=1) + b
    # decode the results, and typecast to double
    y = myclassifier(y)
    y = tf.cast(y, tf.dtypes.double)
    # typecast the known labels to double
    labels = tf.cast(labels, tf.dtypes.double)
    # calculate the error
    avg_error = tf.reduce_mean(tf.square(y - labels))
    per_iter_err.append(avg_error)
    mse_derivative = tf.reduce_mean(2 * ( y - labels ))

    # update the weights and bias for the next epoch
    weight_update = tf.reduce_mean(mse_derivative*data)
    bias_update = tf.reduce_mean(mse_derivative)

    w = w - HP_lr * weight_update
    b = b - HP_lr * bias_update
    # end of iteration simulation

  final_epoch_error = np.array(per_iter_err).mean()
  err.append(final_epoch_error)
  #end of epoch simulation

  print('****')
  print('For epoch ',i+1,', the weights = ', w)
# Out:
# ****
# For epoch  1 , the weights =  tf.Tensor(
# [[-0.45318452]
#  [ 0.04542457]], shape=(2, 1), dtype=float64)
# ****
# For epoch  2 , the weights =  tf.Tensor(
# [[-0.45226376]
#  [ 0.04634533]], shape=(2, 1), dtype=float64)
# ****
# For epoch  3 , the weights =  tf.Tensor(
# [[-0.45100263]
#  [ 0.04760645]], shape=(2, 1), dtype=float64)
# ****
# For epoch  4 , the weights =  tf.Tensor(
# [[-0.44991305]
#  [ 0.04869603]], shape=(2, 1), dtype=float64)
# ****
# For epoch  5 , the weights =  tf.Tensor(
# [[-0.44834868]
#  [ 0.0502604 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  6 , the weights =  tf.Tensor(
# [[-0.44716837]
#  [ 0.05144071]], shape=(2, 1), dtype=float64)
# ****
# For epoch  7 , the weights =  tf.Tensor(
# [[-0.44710817]
#  [ 0.05150092]], shape=(2, 1), dtype=float64)
# ****
# For epoch  8 , the weights =  tf.Tensor(
# [[-0.44699732]
#  [ 0.05161176]], shape=(2, 1), dtype=float64)
# ****
# For epoch  9 , the weights =  tf.Tensor(
# [[-0.44669862]
#  [ 0.05191047]], shape=(2, 1), dtype=float64)
# ****
# For epoch  10 , the weights =  tf.Tensor(
# [[-0.44499049]
#  [ 0.0536186 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  11 , the weights =  tf.Tensor(
# [[-0.44463049]
#  [ 0.0539786 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  12 , the weights =  tf.Tensor(
# [[-0.44375801]
#  [ 0.05485108]], shape=(2, 1), dtype=float64)
# ****
# For epoch  13 , the weights =  tf.Tensor(
# [[-0.44289128]
#  [ 0.0557178 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  14 , the weights =  tf.Tensor(
# [[-0.44152046]
#  [ 0.05708862]], shape=(2, 1), dtype=float64)
# ****
# For epoch  15 , the weights =  tf.Tensor(
# [[-0.44048953]
#  [ 0.05811955]], shape=(2, 1), dtype=float64)
# ****
# For epoch  16 , the weights =  tf.Tensor(
# [[-0.43944792]
#  [ 0.05916116]], shape=(2, 1), dtype=float64)
# ****
# For epoch  17 , the weights =  tf.Tensor(
# [[-0.43867252]
#  [ 0.05993657]], shape=(2, 1), dtype=float64)
# ****
# For epoch  18 , the weights =  tf.Tensor(
# [[-0.43791291]
#  [ 0.06069617]], shape=(2, 1), dtype=float64)
# ****
# For epoch  19 , the weights =  tf.Tensor(
# [[-0.43763353]
#  [ 0.06097556]], shape=(2, 1), dtype=float64)
# ****
# For epoch  20 , the weights =  tf.Tensor(
# [[-0.43757821]
#  [ 0.06103088]], shape=(2, 1), dtype=float64)
# ****
# For epoch  21 , the weights =  tf.Tensor(
# [[-0.43627793]
#  [ 0.06233116]], shape=(2, 1), dtype=float64)
# ****
# For epoch  22 , the weights =  tf.Tensor(
# [[-0.43503673]
#  [ 0.06357236]], shape=(2, 1), dtype=float64)
# ****
# For epoch  23 , the weights =  tf.Tensor(
# [[-0.43403484]
#  [ 0.06457424]], shape=(2, 1), dtype=float64)
# ****
# For epoch  24 , the weights =  tf.Tensor(
# [[-0.43293545]
#  [ 0.06567363]], shape=(2, 1), dtype=float64)
# ****
# For epoch  25 , the weights =  tf.Tensor(
# [[-0.43201501]
#  [ 0.06659407]], shape=(2, 1), dtype=float64)
# ****
# For epoch  26 , the weights =  tf.Tensor(
# [[-0.43094864]
#  [ 0.06766044]], shape=(2, 1), dtype=float64)
# ****
# For epoch  27 , the weights =  tf.Tensor(
# [[-0.43055444]
#  [ 0.06805465]], shape=(2, 1), dtype=float64)
# ****
# For epoch  28 , the weights =  tf.Tensor(
# [[-0.42916431]
#  [ 0.06944477]], shape=(2, 1), dtype=float64)
# ****
# For epoch  29 , the weights =  tf.Tensor(
# [[-0.42773596]
#  [ 0.07087313]], shape=(2, 1), dtype=float64)
# ****
# For epoch  30 , the weights =  tf.Tensor(
# [[-0.42680914]
#  [ 0.07179995]], shape=(2, 1), dtype=float64)
# ****
# For epoch  31 , the weights =  tf.Tensor(
# [[-0.42504774]
#  [ 0.07356135]], shape=(2, 1), dtype=float64)
# ****
# For epoch  32 , the weights =  tf.Tensor(
# [[-0.42414176]
#  [ 0.07446733]], shape=(2, 1), dtype=float64)
# ****
# For epoch  33 , the weights =  tf.Tensor(
# [[-0.42271528]
#  [ 0.07589381]], shape=(2, 1), dtype=float64)
# ****
# For epoch  34 , the weights =  tf.Tensor(
# [[-0.42177077]
#  [ 0.07683832]], shape=(2, 1), dtype=float64)
# ****
# For epoch  35 , the weights =  tf.Tensor(
# [[-0.42057119]
#  [ 0.0780379 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  36 , the weights =  tf.Tensor(
# [[-0.41980932]
#  [ 0.07879976]], shape=(2, 1), dtype=float64)
# ****
# For epoch  37 , the weights =  tf.Tensor(
# [[-0.41907569]
#  [ 0.07953339]], shape=(2, 1), dtype=float64)
# ****
# For epoch  38 , the weights =  tf.Tensor(
# [[-0.41811976]
#  [ 0.08048932]], shape=(2, 1), dtype=float64)
# ****
# For epoch  39 , the weights =  tf.Tensor(
# [[-0.41733863]
#  [ 0.08127046]], shape=(2, 1), dtype=float64)
# ****
# For epoch  40 , the weights =  tf.Tensor(
# [[-0.41679938]
#  [ 0.0818097 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  41 , the weights =  tf.Tensor(
# [[-0.41635713]
#  [ 0.08225196]], shape=(2, 1), dtype=float64)
# ****
# For epoch  42 , the weights =  tf.Tensor(
# [[-0.41514579]
#  [ 0.0834633 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  43 , the weights =  tf.Tensor(
# [[-0.41432485]
#  [ 0.08428423]], shape=(2, 1), dtype=float64)
# ****
# For epoch  44 , the weights =  tf.Tensor(
# [[-0.41272821]
#  [ 0.08588088]], shape=(2, 1), dtype=float64)
# ****
# For epoch  45 , the weights =  tf.Tensor(
# [[-0.4120127 ]
#  [ 0.08659639]], shape=(2, 1), dtype=float64)
# ****
# For epoch  46 , the weights =  tf.Tensor(
# [[-0.41067584]
#  [ 0.08793325]], shape=(2, 1), dtype=float64)
# ****
# For epoch  47 , the weights =  tf.Tensor(
# [[-0.40989421]
#  [ 0.08871487]], shape=(2, 1), dtype=float64)
# ****
# For epoch  48 , the weights =  tf.Tensor(
# [[-0.40945583]
#  [ 0.08915325]], shape=(2, 1), dtype=float64)
# ****
# For epoch  49 , the weights =  tf.Tensor(
# [[-0.40845567]
#  [ 0.09015342]], shape=(2, 1), dtype=float64)
# ****
# For epoch  50 , the weights =  tf.Tensor(
# [[-0.40694073]
#  [ 0.09166836]], shape=(2, 1), dtype=float64)
# ****
# For epoch  51 , the weights =  tf.Tensor(
# [[-0.40543632]
#  [ 0.09317277]], shape=(2, 1), dtype=float64)
# ****
# For epoch  52 , the weights =  tf.Tensor(
# [[-0.40483685]
#  [ 0.09377224]], shape=(2, 1), dtype=float64)
# ****
# For epoch  53 , the weights =  tf.Tensor(
# [[-0.40410339]
#  [ 0.09450569]], shape=(2, 1), dtype=float64)
# ****
# For epoch  54 , the weights =  tf.Tensor(
# [[-0.40331551]
#  [ 0.09529357]], shape=(2, 1), dtype=float64)
# ****
# For epoch  55 , the weights =  tf.Tensor(
# [[-0.40223846]
#  [ 0.09637063]], shape=(2, 1), dtype=float64)
# ****
# For epoch  56 , the weights =  tf.Tensor(
# [[-0.40046264]
#  [ 0.09814645]], shape=(2, 1), dtype=float64)
# ****
# For epoch  57 , the weights =  tf.Tensor(
# [[-0.39880403]
#  [ 0.09980505]], shape=(2, 1), dtype=float64)
# ****
# For epoch  58 , the weights =  tf.Tensor(
# [[-0.39774517]
#  [ 0.10086392]], shape=(2, 1), dtype=float64)
# ****
# For epoch  59 , the weights =  tf.Tensor(
# [[-0.39638316]
#  [ 0.10222592]], shape=(2, 1), dtype=float64)
# ****
# For epoch  60 , the weights =  tf.Tensor(
# [[-0.39532411]
#  [ 0.10328497]], shape=(2, 1), dtype=float64)
# ****
# For epoch  61 , the weights =  tf.Tensor(
# [[-0.39426613]
#  [ 0.10434296]], shape=(2, 1), dtype=float64)
# ****
# For epoch  62 , the weights =  tf.Tensor(
# [[-0.39340231]
#  [ 0.10520678]], shape=(2, 1), dtype=float64)
# ****
# For epoch  63 , the weights =  tf.Tensor(
# [[-0.39214507]
#  [ 0.10646402]], shape=(2, 1), dtype=float64)
# ****
# For epoch  64 , the weights =  tf.Tensor(
# [[-0.39108241]
#  [ 0.10752668]], shape=(2, 1), dtype=float64)
# ****
# For epoch  65 , the weights =  tf.Tensor(
# [[-0.38943568]
#  [ 0.10917341]], shape=(2, 1), dtype=float64)
# ****
# For epoch  66 , the weights =  tf.Tensor(
# [[-0.38781452]
#  [ 0.11079456]], shape=(2, 1), dtype=float64)
# ****
# For epoch  67 , the weights =  tf.Tensor(
# [[-0.38613456]
#  [ 0.11247452]], shape=(2, 1), dtype=float64)
# ****
# For epoch  68 , the weights =  tf.Tensor(
# [[-0.3855022 ]
#  [ 0.11310689]], shape=(2, 1), dtype=float64)
# ****
# For epoch  69 , the weights =  tf.Tensor(
# [[-0.38433252]
#  [ 0.11427656]], shape=(2, 1), dtype=float64)
# ****
# For epoch  70 , the weights =  tf.Tensor(
# [[-0.3839387 ]
#  [ 0.11467039]], shape=(2, 1), dtype=float64)
# ****
# For epoch  71 , the weights =  tf.Tensor(
# [[-0.38302118]
#  [ 0.1155879 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  72 , the weights =  tf.Tensor(
# [[-0.38166547]
#  [ 0.11694362]], shape=(2, 1), dtype=float64)
# ****
# For epoch  73 , the weights =  tf.Tensor(
# [[-0.3806118 ]
#  [ 0.11799728]], shape=(2, 1), dtype=float64)
# ****
# For epoch  74 , the weights =  tf.Tensor(
# [[-0.37927395]
#  [ 0.11933513]], shape=(2, 1), dtype=float64)
# ****
# For epoch  75 , the weights =  tf.Tensor(
# [[-0.37748605]
#  [ 0.12112304]], shape=(2, 1), dtype=float64)
# ****
# For epoch  76 , the weights =  tf.Tensor(
# [[-0.37630958]
#  [ 0.12229951]], shape=(2, 1), dtype=float64)
# ****
# For epoch  77 , the weights =  tf.Tensor(
# [[-0.37415421]
#  [ 0.12445487]], shape=(2, 1), dtype=float64)
# ****
# For epoch  78 , the weights =  tf.Tensor(
# [[-0.37291687]
#  [ 0.12569221]], shape=(2, 1), dtype=float64)
# ****
# For epoch  79 , the weights =  tf.Tensor(
# [[-0.37175108]
#  [ 0.12685801]], shape=(2, 1), dtype=float64)
# ****
# For epoch  80 , the weights =  tf.Tensor(
# [[-0.36975728]
#  [ 0.12885181]], shape=(2, 1), dtype=float64)
# ****
# For epoch  81 , the weights =  tf.Tensor(
# [[-0.36915703]
#  [ 0.12945206]], shape=(2, 1), dtype=float64)
# ****
# For epoch  82 , the weights =  tf.Tensor(
# [[-0.36794284]
#  [ 0.13066625]], shape=(2, 1), dtype=float64)
# ****
# For epoch  83 , the weights =  tf.Tensor(
# [[-0.36722856]
#  [ 0.13138052]], shape=(2, 1), dtype=float64)
# ****
# For epoch  84 , the weights =  tf.Tensor(
# [[-0.36627262]
#  [ 0.13233647]], shape=(2, 1), dtype=float64)
# ****
# For epoch  85 , the weights =  tf.Tensor(
# [[-0.36424788]
#  [ 0.1343612 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  86 , the weights =  tf.Tensor(
# [[-0.36297044]
#  [ 0.13563865]], shape=(2, 1), dtype=float64)
# ****
# For epoch  87 , the weights =  tf.Tensor(
# [[-0.36103385]
#  [ 0.13757523]], shape=(2, 1), dtype=float64)
# ****
# For epoch  88 , the weights =  tf.Tensor(
# [[-0.36039428]
#  [ 0.13821481]], shape=(2, 1), dtype=float64)
# ****
# For epoch  89 , the weights =  tf.Tensor(
# [[-0.35945918]
#  [ 0.13914991]], shape=(2, 1), dtype=float64)
# ****
# For epoch  90 , the weights =  tf.Tensor(
# [[-0.35851716]
#  [ 0.14009193]], shape=(2, 1), dtype=float64)
# ****
# For epoch  91 , the weights =  tf.Tensor(
# [[-0.35773434]
#  [ 0.14087474]], shape=(2, 1), dtype=float64)
# ****
# For epoch  92 , the weights =  tf.Tensor(
# [[-0.35682337]
#  [ 0.14178572]], shape=(2, 1), dtype=float64)
# ****
# For epoch  93 , the weights =  tf.Tensor(
# [[-0.35558077]
#  [ 0.14302831]], shape=(2, 1), dtype=float64)
# ****
# For epoch  94 , the weights =  tf.Tensor(
# [[-0.35405706]
#  [ 0.14455203]], shape=(2, 1), dtype=float64)
# ****
# For epoch  95 , the weights =  tf.Tensor(
# [[-0.35202313]
#  [ 0.14658596]], shape=(2, 1), dtype=float64)
# ****
# For epoch  96 , the weights =  tf.Tensor(
# [[-0.35097844]
#  [ 0.14763064]], shape=(2, 1), dtype=float64)
# ****
# For epoch  97 , the weights =  tf.Tensor(
# [[-0.34988201]
#  [ 0.14872708]], shape=(2, 1), dtype=float64)
# ****
# For epoch  98 , the weights =  tf.Tensor(
# [[-0.34910946]
#  [ 0.14949963]], shape=(2, 1), dtype=float64)
# ****
# For epoch  99 , the weights =  tf.Tensor(
# [[-0.3474092 ]
#  [ 0.15119988]], shape=(2, 1), dtype=float64)
# ****
# For epoch  100 , the weights =  tf.Tensor(
# [[-0.34597818]
#  [ 0.1526309 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  101 , the weights =  tf.Tensor(
# [[-0.34468161]
#  [ 0.15392747]], shape=(2, 1), dtype=float64)
# ****
# For epoch  102 , the weights =  tf.Tensor(
# [[-0.34319631]
#  [ 0.15541278]], shape=(2, 1), dtype=float64)
# ****
# For epoch  103 , the weights =  tf.Tensor(
# [[-0.34267024]
#  [ 0.15593884]], shape=(2, 1), dtype=float64)
# ****
# For epoch  104 , the weights =  tf.Tensor(
# [[-0.34156121]
#  [ 0.15704788]], shape=(2, 1), dtype=float64)
# ****
# For epoch  105 , the weights =  tf.Tensor(
# [[-0.34140359]
#  [ 0.1572055 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  106 , the weights =  tf.Tensor(
# [[-0.34010242]
#  [ 0.15850667]], shape=(2, 1), dtype=float64)
# ****
# For epoch  107 , the weights =  tf.Tensor(
# [[-0.33863563]
#  [ 0.15997346]], shape=(2, 1), dtype=float64)
# ****
# For epoch  108 , the weights =  tf.Tensor(
# [[-0.33666918]
#  [ 0.16193991]], shape=(2, 1), dtype=float64)
# ****
# For epoch  109 , the weights =  tf.Tensor(
# [[-0.33630433]
#  [ 0.16230476]], shape=(2, 1), dtype=float64)
# ****
# For epoch  110 , the weights =  tf.Tensor(
# [[-0.33497468]
#  [ 0.16363441]], shape=(2, 1), dtype=float64)
# ****
# For epoch  111 , the weights =  tf.Tensor(
# [[-0.33361487]
#  [ 0.16499421]], shape=(2, 1), dtype=float64)
# ****
# For epoch  112 , the weights =  tf.Tensor(
# [[-0.33259338]
#  [ 0.1660157 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  113 , the weights =  tf.Tensor(
# [[-0.33116836]
#  [ 0.16744072]], shape=(2, 1), dtype=float64)
# ****
# For epoch  114 , the weights =  tf.Tensor(
# [[-0.33033988]
#  [ 0.16826921]], shape=(2, 1), dtype=float64)
# ****
# For epoch  115 , the weights =  tf.Tensor(
# [[-0.32927247]
#  [ 0.16933662]], shape=(2, 1), dtype=float64)
# ****
# For epoch  116 , the weights =  tf.Tensor(
# [[-0.32788595]
#  [ 0.17072313]], shape=(2, 1), dtype=float64)
# ****
# For epoch  117 , the weights =  tf.Tensor(
# [[-0.32694192]
#  [ 0.17166717]], shape=(2, 1), dtype=float64)
# ****
# For epoch  118 , the weights =  tf.Tensor(
# [[-0.32586677]
#  [ 0.17274232]], shape=(2, 1), dtype=float64)
# ****
# For epoch  119 , the weights =  tf.Tensor(
# [[-0.32484916]
#  [ 0.17375992]], shape=(2, 1), dtype=float64)
# ****
# For epoch  120 , the weights =  tf.Tensor(
# [[-0.32404378]
#  [ 0.17456531]], shape=(2, 1), dtype=float64)
# ****
# For epoch  121 , the weights =  tf.Tensor(
# [[-0.32342932]
#  [ 0.17517977]], shape=(2, 1), dtype=float64)
# ****
# For epoch  122 , the weights =  tf.Tensor(
# [[-0.32189312]
#  [ 0.17671596]], shape=(2, 1), dtype=float64)
# ****
# For epoch  123 , the weights =  tf.Tensor(
# [[-0.32053463]
#  [ 0.17807446]], shape=(2, 1), dtype=float64)
# ****
# For epoch  124 , the weights =  tf.Tensor(
# [[-0.31912592]
#  [ 0.17948316]], shape=(2, 1), dtype=float64)
# ****
# For epoch  125 , the weights =  tf.Tensor(
# [[-0.31797068]
#  [ 0.1806384 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  126 , the weights =  tf.Tensor(
# [[-0.31678619]
#  [ 0.18182289]], shape=(2, 1), dtype=float64)
# ****
# For epoch  127 , the weights =  tf.Tensor(
# [[-0.31647198]
#  [ 0.1821371 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  128 , the weights =  tf.Tensor(
# [[-0.31488719]
#  [ 0.18372189]], shape=(2, 1), dtype=float64)
# ****
# For epoch  129 , the weights =  tf.Tensor(
# [[-0.31390781]
#  [ 0.18470127]], shape=(2, 1), dtype=float64)
# ****
# For epoch  130 , the weights =  tf.Tensor(
# [[-0.31334003]
#  [ 0.18526905]], shape=(2, 1), dtype=float64)
# ****
# For epoch  131 , the weights =  tf.Tensor(
# [[-0.31253776]
#  [ 0.18607133]], shape=(2, 1), dtype=float64)
# ****
# For epoch  132 , the weights =  tf.Tensor(
# [[-0.31059644]
#  [ 0.18801264]], shape=(2, 1), dtype=float64)
# ****
# For epoch  133 , the weights =  tf.Tensor(
# [[-0.30987502]
#  [ 0.18873406]], shape=(2, 1), dtype=float64)
# ****
# For epoch  134 , the weights =  tf.Tensor(
# [[-0.30854539]
#  [ 0.1900637 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  135 , the weights =  tf.Tensor(
# [[-0.30796829]
#  [ 0.1906408 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  136 , the weights =  tf.Tensor(
# [[-0.30725695]
#  [ 0.19135214]], shape=(2, 1), dtype=float64)
# ****
# For epoch  137 , the weights =  tf.Tensor(
# [[-0.30641867]
#  [ 0.19219042]], shape=(2, 1), dtype=float64)
# ****
# For epoch  138 , the weights =  tf.Tensor(
# [[-0.30526756]
#  [ 0.19334153]], shape=(2, 1), dtype=float64)
# ****
# For epoch  139 , the weights =  tf.Tensor(
# [[-0.3044078 ]
#  [ 0.19420128]], shape=(2, 1), dtype=float64)
# ****
# For epoch  140 , the weights =  tf.Tensor(
# [[-0.30376372]
#  [ 0.19484537]], shape=(2, 1), dtype=float64)
# ****
# For epoch  141 , the weights =  tf.Tensor(
# [[-0.30192376]
#  [ 0.19668533]], shape=(2, 1), dtype=float64)
# ****
# For epoch  142 , the weights =  tf.Tensor(
# [[-0.30095363]
#  [ 0.19765546]], shape=(2, 1), dtype=float64)
# ****
# For epoch  143 , the weights =  tf.Tensor(
# [[-0.30023639]
#  [ 0.19837269]], shape=(2, 1), dtype=float64)
# ****
# For epoch  144 , the weights =  tf.Tensor(
# [[-0.29907441]
#  [ 0.19953468]], shape=(2, 1), dtype=float64)
# ****
# For epoch  145 , the weights =  tf.Tensor(
# [[-0.29867655]
#  [ 0.19993254]], shape=(2, 1), dtype=float64)
# ****
# For epoch  146 , the weights =  tf.Tensor(
# [[-0.29786404]
#  [ 0.20074505]], shape=(2, 1), dtype=float64)
# ****
# For epoch  147 , the weights =  tf.Tensor(
# [[-0.29742194]
#  [ 0.20118715]], shape=(2, 1), dtype=float64)
# ****
# For epoch  148 , the weights =  tf.Tensor(
# [[-0.29626371]
#  [ 0.20234537]], shape=(2, 1), dtype=float64)
# ****
# For epoch  149 , the weights =  tf.Tensor(
# [[-0.29575021]
#  [ 0.20285887]], shape=(2, 1), dtype=float64)
# ****
# For epoch  150 , the weights =  tf.Tensor(
# [[-0.29473034]
#  [ 0.20387875]], shape=(2, 1), dtype=float64)
# ****
# For epoch  151 , the weights =  tf.Tensor(
# [[-0.29367517]
#  [ 0.20493392]], shape=(2, 1), dtype=float64)
# ****
# For epoch  152 , the weights =  tf.Tensor(
# [[-0.29263582]
#  [ 0.20597327]], shape=(2, 1), dtype=float64)
# ****
# For epoch  153 , the weights =  tf.Tensor(
# [[-0.29227048]
#  [ 0.2063386 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  154 , the weights =  tf.Tensor(
# [[-0.29067109]
#  [ 0.207938  ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  155 , the weights =  tf.Tensor(
# [[-0.28987448]
#  [ 0.20873461]], shape=(2, 1), dtype=float64)
# ****
# For epoch  156 , the weights =  tf.Tensor(
# [[-0.28820838]
#  [ 0.21040071]], shape=(2, 1), dtype=float64)
# ****
# For epoch  157 , the weights =  tf.Tensor(
# [[-0.2872882 ]
#  [ 0.21132088]], shape=(2, 1), dtype=float64)
# ****
# For epoch  158 , the weights =  tf.Tensor(
# [[-0.28636803]
#  [ 0.21224105]], shape=(2, 1), dtype=float64)
# ****
# For epoch  159 , the weights =  tf.Tensor(
# [[-0.28562838]
#  [ 0.21298071]], shape=(2, 1), dtype=float64)
# ****
# For epoch  160 , the weights =  tf.Tensor(
# [[-0.28467672]
#  [ 0.21393237]], shape=(2, 1), dtype=float64)
# ****
# For epoch  161 , the weights =  tf.Tensor(
# [[-0.28335332]
#  [ 0.21525577]], shape=(2, 1), dtype=float64)
# ****
# For epoch  162 , the weights =  tf.Tensor(
# [[-0.28216808]
#  [ 0.21644101]], shape=(2, 1), dtype=float64)
# ****
# For epoch  163 , the weights =  tf.Tensor(
# [[-0.28071487]
#  [ 0.21789422]], shape=(2, 1), dtype=float64)
# ****
# For epoch  164 , the weights =  tf.Tensor(
# [[-0.27977043]
#  [ 0.21883866]], shape=(2, 1), dtype=float64)
# ****
# For epoch  165 , the weights =  tf.Tensor(
# [[-0.27848092]
#  [ 0.22012817]], shape=(2, 1), dtype=float64)
# ****
# For epoch  166 , the weights =  tf.Tensor(
# [[-0.27789332]
#  [ 0.22071576]], shape=(2, 1), dtype=float64)
# ****
# For epoch  167 , the weights =  tf.Tensor(
# [[-0.2772068 ]
#  [ 0.22140228]], shape=(2, 1), dtype=float64)
# ****
# For epoch  168 , the weights =  tf.Tensor(
# [[-0.2766069 ]
#  [ 0.22200218]], shape=(2, 1), dtype=float64)
# ****
# For epoch  169 , the weights =  tf.Tensor(
# [[-0.27620838]
#  [ 0.22240071]], shape=(2, 1), dtype=float64)
# ****
# For epoch  170 , the weights =  tf.Tensor(
# [[-0.27513832]
#  [ 0.22347076]], shape=(2, 1), dtype=float64)
# ****
# For epoch  171 , the weights =  tf.Tensor(
# [[-0.27472466]
#  [ 0.22388443]], shape=(2, 1), dtype=float64)
# ****
# For epoch  172 , the weights =  tf.Tensor(
# [[-0.2736744 ]
#  [ 0.22493469]], shape=(2, 1), dtype=float64)
# ****
# For epoch  173 , the weights =  tf.Tensor(
# [[-0.27322129]
#  [ 0.22538779]], shape=(2, 1), dtype=float64)
# ****
# For epoch  174 , the weights =  tf.Tensor(
# [[-0.27270575]
#  [ 0.22590333]], shape=(2, 1), dtype=float64)
# ****
# For epoch  175 , the weights =  tf.Tensor(
# [[-0.27152852]
#  [ 0.22708057]], shape=(2, 1), dtype=float64)
# ****
# For epoch  176 , the weights =  tf.Tensor(
# [[-0.27042544]
#  [ 0.22818364]], shape=(2, 1), dtype=float64)
# ****
# For epoch  177 , the weights =  tf.Tensor(
# [[-0.26946802]
#  [ 0.22914106]], shape=(2, 1), dtype=float64)
# ****
# For epoch  178 , the weights =  tf.Tensor(
# [[-0.26840824]
#  [ 0.23020085]], shape=(2, 1), dtype=float64)
# ****
# For epoch  179 , the weights =  tf.Tensor(
# [[-0.26785233]
#  [ 0.23075676]], shape=(2, 1), dtype=float64)
# ****
# For epoch  180 , the weights =  tf.Tensor(
# [[-0.26779072]
#  [ 0.23081836]], shape=(2, 1), dtype=float64)
# ****
# For epoch  181 , the weights =  tf.Tensor(
# [[-0.26702863]
#  [ 0.23158046]], shape=(2, 1), dtype=float64)
# ****
# For epoch  182 , the weights =  tf.Tensor(
# [[-0.26623928]
#  [ 0.23236981]], shape=(2, 1), dtype=float64)
# ****
# For epoch  183 , the weights =  tf.Tensor(
# [[-0.26547398]
#  [ 0.23313511]], shape=(2, 1), dtype=float64)
# ****
# For epoch  184 , the weights =  tf.Tensor(
# [[-0.26428777]
#  [ 0.23432132]], shape=(2, 1), dtype=float64)
# ****
# For epoch  185 , the weights =  tf.Tensor(
# [[-0.26320785]
#  [ 0.23540123]], shape=(2, 1), dtype=float64)
# ****
# For epoch  186 , the weights =  tf.Tensor(
# [[-0.26263123]
#  [ 0.23597785]], shape=(2, 1), dtype=float64)
# ****
# For epoch  187 , the weights =  tf.Tensor(
# [[-0.26227857]
#  [ 0.23633051]], shape=(2, 1), dtype=float64)
# ****
# For epoch  188 , the weights =  tf.Tensor(
# [[-0.26144455]
#  [ 0.23716454]], shape=(2, 1), dtype=float64)
# ****
# For epoch  189 , the weights =  tf.Tensor(
# [[-0.26072033]
#  [ 0.23788875]], shape=(2, 1), dtype=float64)
# ****
# For epoch  190 , the weights =  tf.Tensor(
# [[-0.25964515]
#  [ 0.23896394]], shape=(2, 1), dtype=float64)
# ****
# For epoch  191 , the weights =  tf.Tensor(
# [[-0.25872748]
#  [ 0.23988161]], shape=(2, 1), dtype=float64)
# ****
# For epoch  192 , the weights =  tf.Tensor(
# [[-0.25755845]
#  [ 0.24105064]], shape=(2, 1), dtype=float64)
# ****
# For epoch  193 , the weights =  tf.Tensor(
# [[-0.25672024]
#  [ 0.24188884]], shape=(2, 1), dtype=float64)
# ****
# For epoch  194 , the weights =  tf.Tensor(
# [[-0.25560207]
#  [ 0.24300702]], shape=(2, 1), dtype=float64)
# ****
# For epoch  195 , the weights =  tf.Tensor(
# [[-0.2551681 ]
#  [ 0.24344098]], shape=(2, 1), dtype=float64)
# ****
# For epoch  196 , the weights =  tf.Tensor(
# [[-0.25443839]
#  [ 0.2441707 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  197 , the weights =  tf.Tensor(
# [[-0.25384141]
#  [ 0.24476767]], shape=(2, 1), dtype=float64)
# ****
# For epoch  198 , the weights =  tf.Tensor(
# [[-0.25286091]
#  [ 0.24574818]], shape=(2, 1), dtype=float64)
# ****
# For epoch  199 , the weights =  tf.Tensor(
# [[-0.25174141]
#  [ 0.24686767]], shape=(2, 1), dtype=float64)
# ****
# For epoch  200 , the weights =  tf.Tensor(
# [[-0.25075841]
#  [ 0.24785067]], shape=(2, 1), dtype=float64)
# ****
# For epoch  201 , the weights =  tf.Tensor(
# [[-0.24988545]
#  [ 0.24872364]], shape=(2, 1), dtype=float64)
# ****
# For epoch  202 , the weights =  tf.Tensor(
# [[-0.24959036]
#  [ 0.24901873]], shape=(2, 1), dtype=float64)
# ****
# For epoch  203 , the weights =  tf.Tensor(
# [[-0.24924864]
#  [ 0.24936045]], shape=(2, 1), dtype=float64)
# ****
# For epoch  204 , the weights =  tf.Tensor(
# [[-0.24891925]
#  [ 0.24968984]], shape=(2, 1), dtype=float64)
# ****
# For epoch  205 , the weights =  tf.Tensor(
# [[-0.24822859]
#  [ 0.25038049]], shape=(2, 1), dtype=float64)
# ****
# For epoch  206 , the weights =  tf.Tensor(
# [[-0.24720981]
#  [ 0.25139927]], shape=(2, 1), dtype=float64)
# ****
# For epoch  207 , the weights =  tf.Tensor(
# [[-0.24627895]
#  [ 0.25233014]], shape=(2, 1), dtype=float64)
# ****
# For epoch  208 , the weights =  tf.Tensor(
# [[-0.24542196]
#  [ 0.25318713]], shape=(2, 1), dtype=float64)
# ****
# For epoch  209 , the weights =  tf.Tensor(
# [[-0.24515199]
#  [ 0.25345709]], shape=(2, 1), dtype=float64)
# ****
# For epoch  210 , the weights =  tf.Tensor(
# [[-0.24425455]
#  [ 0.25435453]], shape=(2, 1), dtype=float64)
# ****
# For epoch  211 , the weights =  tf.Tensor(
# [[-0.24395249]
#  [ 0.2546566 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  212 , the weights =  tf.Tensor(
# [[-0.24365672]
#  [ 0.25495236]], shape=(2, 1), dtype=float64)
# ****
# For epoch  213 , the weights =  tf.Tensor(
# [[-0.24373408]
#  [ 0.254875  ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  214 , the weights =  tf.Tensor(
# [[-0.24356143]
#  [ 0.25504765]], shape=(2, 1), dtype=float64)
# ****
# For epoch  215 , the weights =  tf.Tensor(
# [[-0.24251643]
#  [ 0.25609266]], shape=(2, 1), dtype=float64)
# ****
# For epoch  216 , the weights =  tf.Tensor(
# [[-0.24133707]
#  [ 0.25727201]], shape=(2, 1), dtype=float64)
# ****
# For epoch  217 , the weights =  tf.Tensor(
# [[-0.24066631]
#  [ 0.25794277]], shape=(2, 1), dtype=float64)
# ****
# For epoch  218 , the weights =  tf.Tensor(
# [[-0.24016294]
#  [ 0.25844614]], shape=(2, 1), dtype=float64)
# ****
# For epoch  219 , the weights =  tf.Tensor(
# [[-0.23954304]
#  [ 0.25906605]], shape=(2, 1), dtype=float64)
# ****
# For epoch  220 , the weights =  tf.Tensor(
# [[-0.23860224]
#  [ 0.26000685]], shape=(2, 1), dtype=float64)
# ****
# For epoch  221 , the weights =  tf.Tensor(
# [[-0.23782882]
#  [ 0.26078026]], shape=(2, 1), dtype=float64)
# ****
# For epoch  222 , the weights =  tf.Tensor(
# [[-0.2368484 ]
#  [ 0.26176069]], shape=(2, 1), dtype=float64)
# ****
# For epoch  223 , the weights =  tf.Tensor(
# [[-0.23623803]
#  [ 0.26237106]], shape=(2, 1), dtype=float64)
# ****
# For epoch  224 , the weights =  tf.Tensor(
# [[-0.23558744]
#  [ 0.26302164]], shape=(2, 1), dtype=float64)
# ****
# For epoch  225 , the weights =  tf.Tensor(
# [[-0.23456636]
#  [ 0.26404273]], shape=(2, 1), dtype=float64)
# ****
# For epoch  226 , the weights =  tf.Tensor(
# [[-0.23421895]
#  [ 0.26439013]], shape=(2, 1), dtype=float64)
# ****
# For epoch  227 , the weights =  tf.Tensor(
# [[-0.2325279 ]
#  [ 0.26608119]], shape=(2, 1), dtype=float64)
# ****
# For epoch  228 , the weights =  tf.Tensor(
# [[-0.23156904]
#  [ 0.26704005]], shape=(2, 1), dtype=float64)
# ****
# For epoch  229 , the weights =  tf.Tensor(
# [[-0.23123876]
#  [ 0.26737032]], shape=(2, 1), dtype=float64)
# ****
# For epoch  230 , the weights =  tf.Tensor(
# [[-0.23059481]
#  [ 0.26801428]], shape=(2, 1), dtype=float64)
# ****
# For epoch  231 , the weights =  tf.Tensor(
# [[-0.22993518]
#  [ 0.2686739 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  232 , the weights =  tf.Tensor(
# [[-0.22902096]
#  [ 0.26958813]], shape=(2, 1), dtype=float64)
# ****
# For epoch  233 , the weights =  tf.Tensor(
# [[-0.22853874]
#  [ 0.27007034]], shape=(2, 1), dtype=float64)
# ****
# For epoch  234 , the weights =  tf.Tensor(
# [[-0.22825127]
#  [ 0.27035782]], shape=(2, 1), dtype=float64)
# ****
# For epoch  235 , the weights =  tf.Tensor(
# [[-0.22747876]
#  [ 0.27113033]], shape=(2, 1), dtype=float64)
# ****
# For epoch  236 , the weights =  tf.Tensor(
# [[-0.22688203]
#  [ 0.27172705]], shape=(2, 1), dtype=float64)
# ****
# For epoch  237 , the weights =  tf.Tensor(
# [[-0.22605874]
#  [ 0.27255034]], shape=(2, 1), dtype=float64)
# ****
# For epoch  238 , the weights =  tf.Tensor(
# [[-0.22485236]
#  [ 0.27375673]], shape=(2, 1), dtype=float64)
# ****
# For epoch  239 , the weights =  tf.Tensor(
# [[-0.22447465]
#  [ 0.27413443]], shape=(2, 1), dtype=float64)
# ****
# For epoch  240 , the weights =  tf.Tensor(
# [[-0.22252317]
#  [ 0.27608592]], shape=(2, 1), dtype=float64)
# ****
# For epoch  241 , the weights =  tf.Tensor(
# [[-0.22158187]
#  [ 0.27702721]], shape=(2, 1), dtype=float64)
# ****
# For epoch  242 , the weights =  tf.Tensor(
# [[-0.22069418]
#  [ 0.27791491]], shape=(2, 1), dtype=float64)
# ****
# For epoch  243 , the weights =  tf.Tensor(
# [[-0.21889876]
#  [ 0.27971032]], shape=(2, 1), dtype=float64)
# ****
# For epoch  244 , the weights =  tf.Tensor(
# [[-0.21824662]
#  [ 0.28036247]], shape=(2, 1), dtype=float64)
# ****
# For epoch  245 , the weights =  tf.Tensor(
# [[-0.21778218]
#  [ 0.28082691]], shape=(2, 1), dtype=float64)
# ****
# For epoch  246 , the weights =  tf.Tensor(
# [[-0.21669094]
#  [ 0.28191814]], shape=(2, 1), dtype=float64)
# ****
# For epoch  247 , the weights =  tf.Tensor(
# [[-0.21591182]
#  [ 0.28269726]], shape=(2, 1), dtype=float64)
# ****
# For epoch  248 , the weights =  tf.Tensor(
# [[-0.21560565]
#  [ 0.28300344]], shape=(2, 1), dtype=float64)
# ****
# For epoch  249 , the weights =  tf.Tensor(
# [[-0.21571378]
#  [ 0.28289531]], shape=(2, 1), dtype=float64)
# ****
# For epoch  250 , the weights =  tf.Tensor(
# [[-0.21516292]
#  [ 0.28344617]], shape=(2, 1), dtype=float64)
# ****
# For epoch  251 , the weights =  tf.Tensor(
# [[-0.21405526]
#  [ 0.28455382]], shape=(2, 1), dtype=float64)
# ****
# For epoch  252 , the weights =  tf.Tensor(
# [[-0.21312684]
#  [ 0.28548225]], shape=(2, 1), dtype=float64)
# ****
# For epoch  253 , the weights =  tf.Tensor(
# [[-0.21287602]
#  [ 0.28573307]], shape=(2, 1), dtype=float64)
# ****
# For epoch  254 , the weights =  tf.Tensor(
# [[-0.21264149]
#  [ 0.28596759]], shape=(2, 1), dtype=float64)
# ****
# For epoch  255 , the weights =  tf.Tensor(
# [[-0.21191666]
#  [ 0.28669243]], shape=(2, 1), dtype=float64)
# ****
# For epoch  256 , the weights =  tf.Tensor(
# [[-0.21149668]
#  [ 0.2871124 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  257 , the weights =  tf.Tensor(
# [[-0.21087884]
#  [ 0.28773025]], shape=(2, 1), dtype=float64)
# ****
# For epoch  258 , the weights =  tf.Tensor(
# [[-0.21006219]
#  [ 0.28854689]], shape=(2, 1), dtype=float64)
# ****
# For epoch  259 , the weights =  tf.Tensor(
# [[-0.20944503]
#  [ 0.28916405]], shape=(2, 1), dtype=float64)
# ****
# For epoch  260 , the weights =  tf.Tensor(
# [[-0.20868672]
#  [ 0.28992236]], shape=(2, 1), dtype=float64)
# ****
# For epoch  261 , the weights =  tf.Tensor(
# [[-0.2085083 ]
#  [ 0.29010078]], shape=(2, 1), dtype=float64)
# ****
# For epoch  262 , the weights =  tf.Tensor(
# [[-0.20803077]
#  [ 0.29057832]], shape=(2, 1), dtype=float64)
# ****
# For epoch  263 , the weights =  tf.Tensor(
# [[-0.20767482]
#  [ 0.29093427]], shape=(2, 1), dtype=float64)
# ****
# For epoch  264 , the weights =  tf.Tensor(
# [[-0.20647885]
#  [ 0.29213023]], shape=(2, 1), dtype=float64)
# ****
# For epoch  265 , the weights =  tf.Tensor(
# [[-0.20608682]
#  [ 0.29252226]], shape=(2, 1), dtype=float64)
# ****
# For epoch  266 , the weights =  tf.Tensor(
# [[-0.20520624]
#  [ 0.29340285]], shape=(2, 1), dtype=float64)
# ****
# For epoch  267 , the weights =  tf.Tensor(
# [[-0.20370799]
#  [ 0.29490109]], shape=(2, 1), dtype=float64)
# ****
# For epoch  268 , the weights =  tf.Tensor(
# [[-0.20328161]
#  [ 0.29532748]], shape=(2, 1), dtype=float64)
# ****
# For epoch  269 , the weights =  tf.Tensor(
# [[-0.20317178]
#  [ 0.29543731]], shape=(2, 1), dtype=float64)
# ****
# For epoch  270 , the weights =  tf.Tensor(
# [[-0.20251093]
#  [ 0.29609816]], shape=(2, 1), dtype=float64)
# ****
# For epoch  271 , the weights =  tf.Tensor(
# [[-0.20200486]
#  [ 0.29660422]], shape=(2, 1), dtype=float64)
# ****
# For epoch  272 , the weights =  tf.Tensor(
# [[-0.20101227]
#  [ 0.29759682]], shape=(2, 1), dtype=float64)
# ****
# For epoch  273 , the weights =  tf.Tensor(
# [[-0.20064096]
#  [ 0.29796813]], shape=(2, 1), dtype=float64)
# ****
# For epoch  274 , the weights =  tf.Tensor(
# [[-0.20001523]
#  [ 0.29859386]], shape=(2, 1), dtype=float64)
# ****
# For epoch  275 , the weights =  tf.Tensor(
# [[-0.19916928]
#  [ 0.2994398 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  276 , the weights =  tf.Tensor(
# [[-0.19920249]
#  [ 0.2994066 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  277 , the weights =  tf.Tensor(
# [[-0.19867795]
#  [ 0.29993114]], shape=(2, 1), dtype=float64)
# ****
# For epoch  278 , the weights =  tf.Tensor(
# [[-0.19795192]
#  [ 0.30065716]], shape=(2, 1), dtype=float64)
# ****
# For epoch  279 , the weights =  tf.Tensor(
# [[-0.19688049]
#  [ 0.30172859]], shape=(2, 1), dtype=float64)
# ****
# For epoch  280 , the weights =  tf.Tensor(
# [[-0.19665913]
#  [ 0.30194996]], shape=(2, 1), dtype=float64)
# ****
# For epoch  281 , the weights =  tf.Tensor(
# [[-0.19601216]
#  [ 0.30259692]], shape=(2, 1), dtype=float64)
# ****
# For epoch  282 , the weights =  tf.Tensor(
# [[-0.19570893]
#  [ 0.30290016]], shape=(2, 1), dtype=float64)
# ****
# For epoch  283 , the weights =  tf.Tensor(
# [[-0.19584589]
#  [ 0.30276319]], shape=(2, 1), dtype=float64)
# ****
# For epoch  284 , the weights =  tf.Tensor(
# [[-0.19523071]
#  [ 0.30337837]], shape=(2, 1), dtype=float64)
# ****
# For epoch  285 , the weights =  tf.Tensor(
# [[-0.19476244]
#  [ 0.30384665]], shape=(2, 1), dtype=float64)
# ****
# For epoch  286 , the weights =  tf.Tensor(
# [[-0.19430469]
#  [ 0.30430439]], shape=(2, 1), dtype=float64)
# ****
# For epoch  287 , the weights =  tf.Tensor(
# [[-0.19387525]
#  [ 0.30473384]], shape=(2, 1), dtype=float64)
# ****
# For epoch  288 , the weights =  tf.Tensor(
# [[-0.19321421]
#  [ 0.30539488]], shape=(2, 1), dtype=float64)
# ****
# For epoch  289 , the weights =  tf.Tensor(
# [[-0.19307509]
#  [ 0.30553399]], shape=(2, 1), dtype=float64)
# ****
# For epoch  290 , the weights =  tf.Tensor(
# [[-0.19226187]
#  [ 0.30634722]], shape=(2, 1), dtype=float64)
# ****
# For epoch  291 , the weights =  tf.Tensor(
# [[-0.1914423 ]
#  [ 0.30716678]], shape=(2, 1), dtype=float64)
# ****
# For epoch  292 , the weights =  tf.Tensor(
# [[-0.19111207]
#  [ 0.30749701]], shape=(2, 1), dtype=float64)
# ****
# For epoch  293 , the weights =  tf.Tensor(
# [[-0.19046838]
#  [ 0.30814071]], shape=(2, 1), dtype=float64)
# ****
# For epoch  294 , the weights =  tf.Tensor(
# [[-0.19031063]
#  [ 0.30829846]], shape=(2, 1), dtype=float64)
# ****
# For epoch  295 , the weights =  tf.Tensor(
# [[-0.18959131]
#  [ 0.30901778]], shape=(2, 1), dtype=float64)
# ****
# For epoch  296 , the weights =  tf.Tensor(
# [[-0.18861056]
#  [ 0.30999853]], shape=(2, 1), dtype=float64)
# ****
# For epoch  297 , the weights =  tf.Tensor(
# [[-0.18762047]
#  [ 0.31098862]], shape=(2, 1), dtype=float64)
# ****
# For epoch  298 , the weights =  tf.Tensor(
# [[-0.18684969]
#  [ 0.3117594 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  299 , the weights =  tf.Tensor(
# [[-0.18609658]
#  [ 0.3125125 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  300 , the weights =  tf.Tensor(
# [[-0.18487778]
#  [ 0.31373131]], shape=(2, 1), dtype=float64)
# ****
# For epoch  301 , the weights =  tf.Tensor(
# [[-0.1844023 ]
#  [ 0.31420679]], shape=(2, 1), dtype=float64)
# ****
# For epoch  302 , the weights =  tf.Tensor(
# [[-0.18331212]
#  [ 0.31529697]], shape=(2, 1), dtype=float64)
# ****
# For epoch  303 , the weights =  tf.Tensor(
# [[-0.18281962]
#  [ 0.31578946]], shape=(2, 1), dtype=float64)
# ****
# For epoch  304 , the weights =  tf.Tensor(
# [[-0.1822903 ]
#  [ 0.31631879]], shape=(2, 1), dtype=float64)
# ****
# For epoch  305 , the weights =  tf.Tensor(
# [[-0.1816478 ]
#  [ 0.31696129]], shape=(2, 1), dtype=float64)
# ****
# For epoch  306 , the weights =  tf.Tensor(
# [[-0.18097759]
#  [ 0.3176315 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  307 , the weights =  tf.Tensor(
# [[-0.18043132]
#  [ 0.31817776]], shape=(2, 1), dtype=float64)
# ****
# For epoch  308 , the weights =  tf.Tensor(
# [[-0.17970973]
#  [ 0.31889936]], shape=(2, 1), dtype=float64)
# ****
# For epoch  309 , the weights =  tf.Tensor(
# [[-0.18002664]
#  [ 0.31858245]], shape=(2, 1), dtype=float64)
# ****
# For epoch  310 , the weights =  tf.Tensor(
# [[-0.17915825]
#  [ 0.31945084]], shape=(2, 1), dtype=float64)
# ****
# For epoch  311 , the weights =  tf.Tensor(
# [[-0.17866394]
#  [ 0.31994514]], shape=(2, 1), dtype=float64)
# ****
# For epoch  312 , the weights =  tf.Tensor(
# [[-0.17803178]
#  [ 0.32057731]], shape=(2, 1), dtype=float64)
# ****
# For epoch  313 , the weights =  tf.Tensor(
# [[-0.17744503]
#  [ 0.32116405]], shape=(2, 1), dtype=float64)
# ****
# For epoch  314 , the weights =  tf.Tensor(
# [[-0.17726444]
#  [ 0.32134465]], shape=(2, 1), dtype=float64)
# ****
# For epoch  315 , the weights =  tf.Tensor(
# [[-0.17666036]
#  [ 0.32194872]], shape=(2, 1), dtype=float64)
# ****
# For epoch  316 , the weights =  tf.Tensor(
# [[-0.17623023]
#  [ 0.32237885]], shape=(2, 1), dtype=float64)
# ****
# For epoch  317 , the weights =  tf.Tensor(
# [[-0.17541162]
#  [ 0.32319746]], shape=(2, 1), dtype=float64)
# ****
# For epoch  318 , the weights =  tf.Tensor(
# [[-0.17456651]
#  [ 0.32404257]], shape=(2, 1), dtype=float64)
# ****
# For epoch  319 , the weights =  tf.Tensor(
# [[-0.17410464]
#  [ 0.32450444]], shape=(2, 1), dtype=float64)
# ****
# For epoch  320 , the weights =  tf.Tensor(
# [[-0.17279955]
#  [ 0.32580954]], shape=(2, 1), dtype=float64)
# ****
# For epoch  321 , the weights =  tf.Tensor(
# [[-0.17222962]
#  [ 0.32637947]], shape=(2, 1), dtype=float64)
# ****
# For epoch  322 , the weights =  tf.Tensor(
# [[-0.17171354]
#  [ 0.32689554]], shape=(2, 1), dtype=float64)
# ****
# For epoch  323 , the weights =  tf.Tensor(
# [[-0.17146561]
#  [ 0.32714348]], shape=(2, 1), dtype=float64)
# ****
# For epoch  324 , the weights =  tf.Tensor(
# [[-0.17102132]
#  [ 0.32758777]], shape=(2, 1), dtype=float64)
# ****
# For epoch  325 , the weights =  tf.Tensor(
# [[-0.17040716]
#  [ 0.32820193]], shape=(2, 1), dtype=float64)
# ****
# For epoch  326 , the weights =  tf.Tensor(
# [[-0.16985557]
#  [ 0.32875352]], shape=(2, 1), dtype=float64)
# ****
# For epoch  327 , the weights =  tf.Tensor(
# [[-0.16948099]
#  [ 0.3291281 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  328 , the weights =  tf.Tensor(
# [[-0.16888841]
#  [ 0.32972067]], shape=(2, 1), dtype=float64)
# ****
# For epoch  329 , the weights =  tf.Tensor(
# [[-0.16857959]
#  [ 0.33002949]], shape=(2, 1), dtype=float64)
# ****
# For epoch  330 , the weights =  tf.Tensor(
# [[-0.16860384]
#  [ 0.33000524]], shape=(2, 1), dtype=float64)
# ****
# For epoch  331 , the weights =  tf.Tensor(
# [[-0.1687312 ]
#  [ 0.32987789]], shape=(2, 1), dtype=float64)
# ****
# For epoch  332 , the weights =  tf.Tensor(
# [[-0.16824849]
#  [ 0.3303606 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  333 , the weights =  tf.Tensor(
# [[-0.16794276]
#  [ 0.33066632]], shape=(2, 1), dtype=float64)
# ****
# For epoch  334 , the weights =  tf.Tensor(
# [[-0.16768036]
#  [ 0.33092872]], shape=(2, 1), dtype=float64)
# ****
# For epoch  335 , the weights =  tf.Tensor(
# [[-0.16743872]
#  [ 0.33117037]], shape=(2, 1), dtype=float64)
# ****
# For epoch  336 , the weights =  tf.Tensor(
# [[-0.16646418]
#  [ 0.3321449 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  337 , the weights =  tf.Tensor(
# [[-0.16682554]
#  [ 0.33178355]], shape=(2, 1), dtype=float64)
# ****
# For epoch  338 , the weights =  tf.Tensor(
# [[-0.16607972]
#  [ 0.33252937]], shape=(2, 1), dtype=float64)
# ****
# For epoch  339 , the weights =  tf.Tensor(
# [[-0.16462455]
#  [ 0.33398454]], shape=(2, 1), dtype=float64)
# ****
# For epoch  340 , the weights =  tf.Tensor(
# [[-0.16436752]
#  [ 0.33424157]], shape=(2, 1), dtype=float64)
# ****
# For epoch  341 , the weights =  tf.Tensor(
# [[-0.16414094]
#  [ 0.33446815]], shape=(2, 1), dtype=float64)
# ****
# For epoch  342 , the weights =  tf.Tensor(
# [[-0.16430053]
#  [ 0.33430856]], shape=(2, 1), dtype=float64)
# ****
# For epoch  343 , the weights =  tf.Tensor(
# [[-0.16355317]
#  [ 0.33505591]], shape=(2, 1), dtype=float64)
# ****
# For epoch  344 , the weights =  tf.Tensor(
# [[-0.16290222]
#  [ 0.33570686]], shape=(2, 1), dtype=float64)
# ****
# For epoch  345 , the weights =  tf.Tensor(
# [[-0.16250467]
#  [ 0.33610442]], shape=(2, 1), dtype=float64)
# ****
# For epoch  346 , the weights =  tf.Tensor(
# [[-0.16184564]
#  [ 0.33676345]], shape=(2, 1), dtype=float64)
# ****
# For epoch  347 , the weights =  tf.Tensor(
# [[-0.16152519]
#  [ 0.3370839 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  348 , the weights =  tf.Tensor(
# [[-0.16112369]
#  [ 0.3374854 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  349 , the weights =  tf.Tensor(
# [[-0.160865  ]
#  [ 0.33774408]], shape=(2, 1), dtype=float64)
# ****
# For epoch  350 , the weights =  tf.Tensor(
# [[-0.16058271]
#  [ 0.33802638]], shape=(2, 1), dtype=float64)
# ****
# For epoch  351 , the weights =  tf.Tensor(
# [[-0.16007767]
#  [ 0.33853142]], shape=(2, 1), dtype=float64)
# ****
# For epoch  352 , the weights =  tf.Tensor(
# [[-0.15965423]
#  [ 0.33895486]], shape=(2, 1), dtype=float64)
# ****
# For epoch  353 , the weights =  tf.Tensor(
# [[-0.15902202]
#  [ 0.33958707]], shape=(2, 1), dtype=float64)
# ****
# For epoch  354 , the weights =  tf.Tensor(
# [[-0.15861193]
#  [ 0.33999716]], shape=(2, 1), dtype=float64)
# ****
# For epoch  355 , the weights =  tf.Tensor(
# [[-0.15811344]
#  [ 0.34049565]], shape=(2, 1), dtype=float64)
# ****
# For epoch  356 , the weights =  tf.Tensor(
# [[-0.15755295]
#  [ 0.34105614]], shape=(2, 1), dtype=float64)
# ****
# For epoch  357 , the weights =  tf.Tensor(
# [[-0.15721592]
#  [ 0.34139317]], shape=(2, 1), dtype=float64)
# ****
# For epoch  358 , the weights =  tf.Tensor(
# [[-0.15675668]
#  [ 0.34185241]], shape=(2, 1), dtype=float64)
# ****
# For epoch  359 , the weights =  tf.Tensor(
# [[-0.1563621 ]
#  [ 0.34224699]], shape=(2, 1), dtype=float64)
# ****
# For epoch  360 , the weights =  tf.Tensor(
# [[-0.15615681]
#  [ 0.34245228]], shape=(2, 1), dtype=float64)
# ****
# For epoch  361 , the weights =  tf.Tensor(
# [[-0.15582302]
#  [ 0.34278607]], shape=(2, 1), dtype=float64)
# ****
# For epoch  362 , the weights =  tf.Tensor(
# [[-0.15517968]
#  [ 0.34342941]], shape=(2, 1), dtype=float64)
# ****
# For epoch  363 , the weights =  tf.Tensor(
# [[-0.1546153 ]
#  [ 0.34399378]], shape=(2, 1), dtype=float64)
# ****
# For epoch  364 , the weights =  tf.Tensor(
# [[-0.1540054 ]
#  [ 0.34460369]], shape=(2, 1), dtype=float64)
# ****
# For epoch  365 , the weights =  tf.Tensor(
# [[-0.15366108]
#  [ 0.34494801]], shape=(2, 1), dtype=float64)
# ****
# For epoch  366 , the weights =  tf.Tensor(
# [[-0.15328427]
#  [ 0.34532481]], shape=(2, 1), dtype=float64)
# ****
# For epoch  367 , the weights =  tf.Tensor(
# [[-0.15334615]
#  [ 0.34526293]], shape=(2, 1), dtype=float64)
# ****
# For epoch  368 , the weights =  tf.Tensor(
# [[-0.15323749]
#  [ 0.34537159]], shape=(2, 1), dtype=float64)
# ****
# For epoch  369 , the weights =  tf.Tensor(
# [[-0.1524506 ]
#  [ 0.34615849]], shape=(2, 1), dtype=float64)
# ****
# For epoch  370 , the weights =  tf.Tensor(
# [[-0.15227857]
#  [ 0.34633051]], shape=(2, 1), dtype=float64)
# ****
# For epoch  371 , the weights =  tf.Tensor(
# [[-0.1514779 ]
#  [ 0.34713119]], shape=(2, 1), dtype=float64)
# ****
# For epoch  372 , the weights =  tf.Tensor(
# [[-0.15117312]
#  [ 0.34743596]], shape=(2, 1), dtype=float64)
# ****
# For epoch  373 , the weights =  tf.Tensor(
# [[-0.15121871]
#  [ 0.34739038]], shape=(2, 1), dtype=float64)
# ****
# For epoch  374 , the weights =  tf.Tensor(
# [[-0.15052383]
#  [ 0.34808526]], shape=(2, 1), dtype=float64)
# ****
# For epoch  375 , the weights =  tf.Tensor(
# [[-0.15049239]
#  [ 0.3481167 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  376 , the weights =  tf.Tensor(
# [[-0.14997275]
#  [ 0.34863633]], shape=(2, 1), dtype=float64)
# ****
# For epoch  377 , the weights =  tf.Tensor(
# [[-0.14972655]
#  [ 0.34888254]], shape=(2, 1), dtype=float64)
# ****
# For epoch  378 , the weights =  tf.Tensor(
# [[-0.14893684]
#  [ 0.34967225]], shape=(2, 1), dtype=float64)
# ****
# For epoch  379 , the weights =  tf.Tensor(
# [[-0.14888062]
#  [ 0.34972846]], shape=(2, 1), dtype=float64)
# ****
# For epoch  380 , the weights =  tf.Tensor(
# [[-0.14839961]
#  [ 0.35020948]], shape=(2, 1), dtype=float64)
# ****
# For epoch  381 , the weights =  tf.Tensor(
# [[-0.14835763]
#  [ 0.35025145]], shape=(2, 1), dtype=float64)
# ****
# For epoch  382 , the weights =  tf.Tensor(
# [[-0.14829669]
#  [ 0.3503124 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  383 , the weights =  tf.Tensor(
# [[-0.14791876]
#  [ 0.35069032]], shape=(2, 1), dtype=float64)
# ****
# For epoch  384 , the weights =  tf.Tensor(
# [[-0.14758801]
#  [ 0.35102108]], shape=(2, 1), dtype=float64)
# ****
# For epoch  385 , the weights =  tf.Tensor(
# [[-0.14719235]
#  [ 0.35141674]], shape=(2, 1), dtype=float64)
# ****
# For epoch  386 , the weights =  tf.Tensor(
# [[-0.14698453]
#  [ 0.35162455]], shape=(2, 1), dtype=float64)
# ****
# For epoch  387 , the weights =  tf.Tensor(
# [[-0.1464673 ]
#  [ 0.35214178]], shape=(2, 1), dtype=float64)
# ****
# For epoch  388 , the weights =  tf.Tensor(
# [[-0.14572559]
#  [ 0.3528835 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  389 , the weights =  tf.Tensor(
# [[-0.14549417]
#  [ 0.35311491]], shape=(2, 1), dtype=float64)
# ****
# For epoch  390 , the weights =  tf.Tensor(
# [[-0.14531959]
#  [ 0.3532895 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  391 , the weights =  tf.Tensor(
# [[-0.14516552]
#  [ 0.35344357]], shape=(2, 1), dtype=float64)
# ****
# For epoch  392 , the weights =  tf.Tensor(
# [[-0.14483825]
#  [ 0.35377083]], shape=(2, 1), dtype=float64)
# ****
# For epoch  393 , the weights =  tf.Tensor(
# [[-0.14453905]
#  [ 0.35407004]], shape=(2, 1), dtype=float64)
# ****
# For epoch  394 , the weights =  tf.Tensor(
# [[-0.14445037]
#  [ 0.35415871]], shape=(2, 1), dtype=float64)
# ****
# For epoch  395 , the weights =  tf.Tensor(
# [[-0.14369757]
#  [ 0.35491152]], shape=(2, 1), dtype=float64)
# ****
# For epoch  396 , the weights =  tf.Tensor(
# [[-0.14322904]
#  [ 0.35538005]], shape=(2, 1), dtype=float64)
# ****
# For epoch  397 , the weights =  tf.Tensor(
# [[-0.1426801 ]
#  [ 0.35592899]], shape=(2, 1), dtype=float64)
# ****
# For epoch  398 , the weights =  tf.Tensor(
# [[-0.14189921]
#  [ 0.35670988]], shape=(2, 1), dtype=float64)
# ****
# For epoch  399 , the weights =  tf.Tensor(
# [[-0.14155527]
#  [ 0.35705382]], shape=(2, 1), dtype=float64)
# ****
# For epoch  400 , the weights =  tf.Tensor(
# [[-0.14097737]
#  [ 0.35763172]], shape=(2, 1), dtype=float64)
# ****
# For epoch  401 , the weights =  tf.Tensor(
# [[-0.14054251]
#  [ 0.35806658]], shape=(2, 1), dtype=float64)
# ****
# For epoch  402 , the weights =  tf.Tensor(
# [[-0.14091437]
#  [ 0.35769472]], shape=(2, 1), dtype=float64)
# ****
# For epoch  403 , the weights =  tf.Tensor(
# [[-0.14072433]
#  [ 0.35788476]], shape=(2, 1), dtype=float64)
# ****
# For epoch  404 , the weights =  tf.Tensor(
# [[-0.13996077]
#  [ 0.35864831]], shape=(2, 1), dtype=float64)
# ****
# For epoch  405 , the weights =  tf.Tensor(
# [[-0.13977885]
#  [ 0.35883023]], shape=(2, 1), dtype=float64)
# ****
# For epoch  406 , the weights =  tf.Tensor(
# [[-0.13951378]
#  [ 0.35909531]], shape=(2, 1), dtype=float64)
# ****
# For epoch  407 , the weights =  tf.Tensor(
# [[-0.13900779]
#  [ 0.3596013 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  408 , the weights =  tf.Tensor(
# [[-0.13860038]
#  [ 0.3600087 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  409 , the weights =  tf.Tensor(
# [[-0.13856722]
#  [ 0.36004186]], shape=(2, 1), dtype=float64)
# ****
# For epoch  410 , the weights =  tf.Tensor(
# [[-0.13833576]
#  [ 0.36027333]], shape=(2, 1), dtype=float64)
# ****
# For epoch  411 , the weights =  tf.Tensor(
# [[-0.13791917]
#  [ 0.36068991]], shape=(2, 1), dtype=float64)
# ****
# For epoch  412 , the weights =  tf.Tensor(
# [[-0.13741458]
#  [ 0.3611945 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  413 , the weights =  tf.Tensor(
# [[-0.13664018]
#  [ 0.36196891]], shape=(2, 1), dtype=float64)
# ****
# For epoch  414 , the weights =  tf.Tensor(
# [[-0.13623928]
#  [ 0.36236981]], shape=(2, 1), dtype=float64)
# ****
# For epoch  415 , the weights =  tf.Tensor(
# [[-0.13581783]
#  [ 0.36279126]], shape=(2, 1), dtype=float64)
# ****
# For epoch  416 , the weights =  tf.Tensor(
# [[-0.13494085]
#  [ 0.36366823]], shape=(2, 1), dtype=float64)
# ****
# For epoch  417 , the weights =  tf.Tensor(
# [[-0.13425864]
#  [ 0.36435045]], shape=(2, 1), dtype=float64)
# ****
# For epoch  418 , the weights =  tf.Tensor(
# [[-0.13438527]
#  [ 0.36422381]], shape=(2, 1), dtype=float64)
# ****
# For epoch  419 , the weights =  tf.Tensor(
# [[-0.13394475]
#  [ 0.36466433]], shape=(2, 1), dtype=float64)
# ****
# For epoch  420 , the weights =  tf.Tensor(
# [[-0.13368353]
#  [ 0.36492556]], shape=(2, 1), dtype=float64)
# ****
# For epoch  421 , the weights =  tf.Tensor(
# [[-0.13309509]
#  [ 0.365514  ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  422 , the weights =  tf.Tensor(
# [[-0.13257817]
#  [ 0.36603092]], shape=(2, 1), dtype=float64)
# ****
# For epoch  423 , the weights =  tf.Tensor(
# [[-0.13255981]
#  [ 0.36604928]], shape=(2, 1), dtype=float64)
# ****
# For epoch  424 , the weights =  tf.Tensor(
# [[-0.13215273]
#  [ 0.36645636]], shape=(2, 1), dtype=float64)
# ****
# For epoch  425 , the weights =  tf.Tensor(
# [[-0.13099766]
#  [ 0.36761143]], shape=(2, 1), dtype=float64)
# ****
# For epoch  426 , the weights =  tf.Tensor(
# [[-0.1304571 ]
#  [ 0.36815199]], shape=(2, 1), dtype=float64)
# ****
# For epoch  427 , the weights =  tf.Tensor(
# [[-0.13032566]
#  [ 0.36828343]], shape=(2, 1), dtype=float64)
# ****
# For epoch  428 , the weights =  tf.Tensor(
# [[-0.13018659]
#  [ 0.3684225 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  429 , the weights =  tf.Tensor(
# [[-0.1298427 ]
#  [ 0.36876638]], shape=(2, 1), dtype=float64)
# ****
# For epoch  430 , the weights =  tf.Tensor(
# [[-0.13016039]
#  [ 0.36844869]], shape=(2, 1), dtype=float64)
# ****
# For epoch  431 , the weights =  tf.Tensor(
# [[-0.13025043]
#  [ 0.36835866]], shape=(2, 1), dtype=float64)
# ****
# For epoch  432 , the weights =  tf.Tensor(
# [[-0.12936342]
#  [ 0.36924567]], shape=(2, 1), dtype=float64)
# ****
# For epoch  433 , the weights =  tf.Tensor(
# [[-0.1289532 ]
#  [ 0.36965588]], shape=(2, 1), dtype=float64)
# ****
# For epoch  434 , the weights =  tf.Tensor(
# [[-0.12912118]
#  [ 0.3694879 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  435 , the weights =  tf.Tensor(
# [[-0.12838357]
#  [ 0.37022552]], shape=(2, 1), dtype=float64)
# ****
# For epoch  436 , the weights =  tf.Tensor(
# [[-0.12790118]
#  [ 0.37070791]], shape=(2, 1), dtype=float64)
# ****
# For epoch  437 , the weights =  tf.Tensor(
# [[-0.1271903 ]
#  [ 0.37141879]], shape=(2, 1), dtype=float64)
# ****
# For epoch  438 , the weights =  tf.Tensor(
# [[-0.12666014]
#  [ 0.37194895]], shape=(2, 1), dtype=float64)
# ****
# For epoch  439 , the weights =  tf.Tensor(
# [[-0.12631298]
#  [ 0.37229611]], shape=(2, 1), dtype=float64)
# ****
# For epoch  440 , the weights =  tf.Tensor(
# [[-0.12621135]
#  [ 0.37239774]], shape=(2, 1), dtype=float64)
# ****
# For epoch  441 , the weights =  tf.Tensor(
# [[-0.12586633]
#  [ 0.37274276]], shape=(2, 1), dtype=float64)
# ****
# ...
# ****
# For epoch  855 , the weights =  tf.Tensor(
# [[-0.02093873]
#  [ 0.47767035]], shape=(2, 1), dtype=float64)
# ****
# For epoch  856 , the weights =  tf.Tensor(
# [[-0.02018029]
#  [ 0.4784288 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  857 , the weights =  tf.Tensor(
# [[-0.01953926]
#  [ 0.47906982]], shape=(2, 1), dtype=float64)
# ****
# For epoch  858 , the weights =  tf.Tensor(
# [[-0.01964941]
#  [ 0.47895968]], shape=(2, 1), dtype=float64)
# ****
# For epoch  859 , the weights =  tf.Tensor(
# [[-0.01934888]
#  [ 0.47926021]], shape=(2, 1), dtype=float64)
# ****
# For epoch  860 , the weights =  tf.Tensor(
# [[-0.01929637]
#  [ 0.47931272]], shape=(2, 1), dtype=float64)
# ****
# For epoch  861 , the weights =  tf.Tensor(
# [[-0.0195236 ]
#  [ 0.47908549]], shape=(2, 1), dtype=float64)
# ****
# For epoch  862 , the weights =  tf.Tensor(
# [[-0.01947473]
#  [ 0.47913436]], shape=(2, 1), dtype=float64)
# ****
# For epoch  863 , the weights =  tf.Tensor(
# [[-0.01924403]
#  [ 0.47936505]], shape=(2, 1), dtype=float64)
# ****
# For epoch  864 , the weights =  tf.Tensor(
# [[-0.01923699]
#  [ 0.47937209]], shape=(2, 1), dtype=float64)
# ****
# For epoch  865 , the weights =  tf.Tensor(
# [[-0.01894129]
#  [ 0.4796678 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  866 , the weights =  tf.Tensor(
# [[-0.018968  ]
#  [ 0.47964109]], shape=(2, 1), dtype=float64)
# ****
# For epoch  867 , the weights =  tf.Tensor(
# [[-0.0186235 ]
#  [ 0.47998559]], shape=(2, 1), dtype=float64)
# ****
# For epoch  868 , the weights =  tf.Tensor(
# [[-0.0181518 ]
#  [ 0.48045728]], shape=(2, 1), dtype=float64)
# ****
# For epoch  869 , the weights =  tf.Tensor(
# [[-0.01792385]
#  [ 0.48068523]], shape=(2, 1), dtype=float64)
# ****
# For epoch  870 , the weights =  tf.Tensor(
# [[-0.01802901]
#  [ 0.48058007]], shape=(2, 1), dtype=float64)
# ****
# For epoch  871 , the weights =  tf.Tensor(
# [[-0.01829511]
#  [ 0.48031398]], shape=(2, 1), dtype=float64)
# ****
# For epoch  872 , the weights =  tf.Tensor(
# [[-0.0180367 ]
#  [ 0.48057238]], shape=(2, 1), dtype=float64)
# ****
# For epoch  873 , the weights =  tf.Tensor(
# [[-0.01794732]
#  [ 0.48066177]], shape=(2, 1), dtype=float64)
# ****
# For epoch  874 , the weights =  tf.Tensor(
# [[-0.01762697]
#  [ 0.48098212]], shape=(2, 1), dtype=float64)
# ****
# For epoch  875 , the weights =  tf.Tensor(
# [[-0.01772355]
#  [ 0.48088553]], shape=(2, 1), dtype=float64)
# ****
# For epoch  876 , the weights =  tf.Tensor(
# [[-0.01789927]
#  [ 0.48070982]], shape=(2, 1), dtype=float64)
# ****
# For epoch  877 , the weights =  tf.Tensor(
# [[-0.01799666]
#  [ 0.48061242]], shape=(2, 1), dtype=float64)
# ****
# For epoch  878 , the weights =  tf.Tensor(
# [[-0.01801433]
#  [ 0.48059475]], shape=(2, 1), dtype=float64)
# ****
# For epoch  879 , the weights =  tf.Tensor(
# [[-0.01811398]
#  [ 0.4804951 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  880 , the weights =  tf.Tensor(
# [[-0.01828288]
#  [ 0.4803262 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  881 , the weights =  tf.Tensor(
# [[-0.01792317]
#  [ 0.48068592]], shape=(2, 1), dtype=float64)
# ****
# For epoch  882 , the weights =  tf.Tensor(
# [[-0.0170684 ]
#  [ 0.48154068]], shape=(2, 1), dtype=float64)
# ****
# For epoch  883 , the weights =  tf.Tensor(
# [[-0.01675443]
#  [ 0.48185465]], shape=(2, 1), dtype=float64)
# ****
# For epoch  884 , the weights =  tf.Tensor(
# [[-0.0166248 ]
#  [ 0.48198428]], shape=(2, 1), dtype=float64)
# ****
# For epoch  885 , the weights =  tf.Tensor(
# [[-0.01658461]
#  [ 0.48202448]], shape=(2, 1), dtype=float64)
# ****
# For epoch  886 , the weights =  tf.Tensor(
# [[-0.0161217 ]
#  [ 0.48248738]], shape=(2, 1), dtype=float64)
# ****
# For epoch  887 , the weights =  tf.Tensor(
# [[-0.01652755]
#  [ 0.48208154]], shape=(2, 1), dtype=float64)
# ****
# For epoch  888 , the weights =  tf.Tensor(
# [[-0.01637793]
#  [ 0.48223116]], shape=(2, 1), dtype=float64)
# ****
# For epoch  889 , the weights =  tf.Tensor(
# [[-0.0161095 ]
#  [ 0.48249959]], shape=(2, 1), dtype=float64)
# ****
# For epoch  890 , the weights =  tf.Tensor(
# [[-0.0163283 ]
#  [ 0.48228078]], shape=(2, 1), dtype=float64)
# ****
# For epoch  891 , the weights =  tf.Tensor(
# [[-0.01608147]
#  [ 0.48252761]], shape=(2, 1), dtype=float64)
# ****
# For epoch  892 , the weights =  tf.Tensor(
# [[-0.01594907]
#  [ 0.48266001]], shape=(2, 1), dtype=float64)
# ****
# For epoch  893 , the weights =  tf.Tensor(
# [[-0.01549605]
#  [ 0.48311303]], shape=(2, 1), dtype=float64)
# ****
# For epoch  894 , the weights =  tf.Tensor(
# [[-0.01507047]
#  [ 0.48353861]], shape=(2, 1), dtype=float64)
# ****
# For epoch  895 , the weights =  tf.Tensor(
# [[-0.01511797]
#  [ 0.48349112]], shape=(2, 1), dtype=float64)
# ****
# For epoch  896 , the weights =  tf.Tensor(
# [[-0.0147578 ]
#  [ 0.48385128]], shape=(2, 1), dtype=float64)
# ****
# For epoch  897 , the weights =  tf.Tensor(
# [[-0.01463834]
#  [ 0.48397075]], shape=(2, 1), dtype=float64)
# ****
# For epoch  898 , the weights =  tf.Tensor(
# [[-0.0148833 ]
#  [ 0.48372579]], shape=(2, 1), dtype=float64)
# ****
# For epoch  899 , the weights =  tf.Tensor(
# [[-0.0148927 ]
#  [ 0.48371638]], shape=(2, 1), dtype=float64)
# ****
# For epoch  900 , the weights =  tf.Tensor(
# [[-0.01497065]
#  [ 0.48363843]], shape=(2, 1), dtype=float64)
# ****
# For epoch  901 , the weights =  tf.Tensor(
# [[-0.01450532]
#  [ 0.48410377]], shape=(2, 1), dtype=float64)
# ****
# For epoch  902 , the weights =  tf.Tensor(
# [[-0.01469791]
#  [ 0.48391118]], shape=(2, 1), dtype=float64)
# ****
# For epoch  903 , the weights =  tf.Tensor(
# [[-0.01446012]
#  [ 0.48414897]], shape=(2, 1), dtype=float64)
# ****
# For epoch  904 , the weights =  tf.Tensor(
# [[-0.01389303]
#  [ 0.48471606]], shape=(2, 1), dtype=float64)
# ****
# For epoch  905 , the weights =  tf.Tensor(
# [[-0.01341079]
#  [ 0.4851983 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  906 , the weights =  tf.Tensor(
# [[-0.01300617]
#  [ 0.48560291]], shape=(2, 1), dtype=float64)
# ****
# For epoch  907 , the weights =  tf.Tensor(
# [[-0.01287993]
#  [ 0.48572916]], shape=(2, 1), dtype=float64)
# ****
# For epoch  908 , the weights =  tf.Tensor(
# [[-0.0123005 ]
#  [ 0.48630858]], shape=(2, 1), dtype=float64)
# ****
# For epoch  909 , the weights =  tf.Tensor(
# [[-0.01190373]
#  [ 0.48670535]], shape=(2, 1), dtype=float64)
# ****
# For epoch  910 , the weights =  tf.Tensor(
# [[-0.01163074]
#  [ 0.48697835]], shape=(2, 1), dtype=float64)
# ****
# For epoch  911 , the weights =  tf.Tensor(
# [[-0.01175806]
#  [ 0.48685103]], shape=(2, 1), dtype=float64)
# ****
# For epoch  912 , the weights =  tf.Tensor(
# [[-0.01149829]
#  [ 0.48711079]], shape=(2, 1), dtype=float64)
# ****
# For epoch  913 , the weights =  tf.Tensor(
# [[-0.01104677]
#  [ 0.48756232]], shape=(2, 1), dtype=float64)
# ****
# For epoch  914 , the weights =  tf.Tensor(
# [[-0.01088657]
#  [ 0.48772251]], shape=(2, 1), dtype=float64)
# ****
# For epoch  915 , the weights =  tf.Tensor(
# [[-0.01086205]
#  [ 0.48774703]], shape=(2, 1), dtype=float64)
# ****
# For epoch  916 , the weights =  tf.Tensor(
# [[-0.010826  ]
#  [ 0.48778309]], shape=(2, 1), dtype=float64)
# ****
# For epoch  917 , the weights =  tf.Tensor(
# [[-0.01020764]
#  [ 0.48840144]], shape=(2, 1), dtype=float64)
# ****
# For epoch  918 , the weights =  tf.Tensor(
# [[-0.01000967]
#  [ 0.48859942]], shape=(2, 1), dtype=float64)
# ****
# For epoch  919 , the weights =  tf.Tensor(
# [[-0.00964889]
#  [ 0.4889602 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  920 , the weights =  tf.Tensor(
# [[-0.00976166]
#  [ 0.48884742]], shape=(2, 1), dtype=float64)
# ****
# For epoch  921 , the weights =  tf.Tensor(
# [[-0.01021333]
#  [ 0.48839575]], shape=(2, 1), dtype=float64)
# ****
# For epoch  922 , the weights =  tf.Tensor(
# [[-0.01048701]
#  [ 0.48812208]], shape=(2, 1), dtype=float64)
# ****
# For epoch  923 , the weights =  tf.Tensor(
# [[-0.01040495]
#  [ 0.48820413]], shape=(2, 1), dtype=float64)
# ****
# For epoch  924 , the weights =  tf.Tensor(
# [[-0.01080274]
#  [ 0.48780634]], shape=(2, 1), dtype=float64)
# ****
# For epoch  925 , the weights =  tf.Tensor(
# [[-0.01081169]
#  [ 0.4877974 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  926 , the weights =  tf.Tensor(
# [[-0.01078983]
#  [ 0.48781926]], shape=(2, 1), dtype=float64)
# ****
# For epoch  927 , the weights =  tf.Tensor(
# [[-0.010768  ]
#  [ 0.48784108]], shape=(2, 1), dtype=float64)
# ****
# For epoch  928 , the weights =  tf.Tensor(
# [[-0.01096464]
#  [ 0.48764445]], shape=(2, 1), dtype=float64)
# ****
# For epoch  929 , the weights =  tf.Tensor(
# [[-0.01096372]
#  [ 0.48764537]], shape=(2, 1), dtype=float64)
# ****
# For epoch  930 , the weights =  tf.Tensor(
# [[-0.01126808]
#  [ 0.48734101]], shape=(2, 1), dtype=float64)
# ****
# For epoch  931 , the weights =  tf.Tensor(
# [[-0.01139911]
#  [ 0.48720997]], shape=(2, 1), dtype=float64)
# ****
# For epoch  932 , the weights =  tf.Tensor(
# [[-0.0110933 ]
#  [ 0.48751578]], shape=(2, 1), dtype=float64)
# ****
# For epoch  933 , the weights =  tf.Tensor(
# [[-0.01109003]
#  [ 0.48751905]], shape=(2, 1), dtype=float64)
# ****
# For epoch  934 , the weights =  tf.Tensor(
# [[-0.01087097]
#  [ 0.48773811]], shape=(2, 1), dtype=float64)
# ****
# For epoch  935 , the weights =  tf.Tensor(
# [[-0.0104865 ]
#  [ 0.48812259]], shape=(2, 1), dtype=float64)
# ****
# For epoch  936 , the weights =  tf.Tensor(
# [[-0.01052156]
#  [ 0.48808753]], shape=(2, 1), dtype=float64)
# ****
# For epoch  937 , the weights =  tf.Tensor(
# [[-0.0102114 ]
#  [ 0.48839768]], shape=(2, 1), dtype=float64)
# ****
# For epoch  938 , the weights =  tf.Tensor(
# [[-0.01027613]
#  [ 0.48833295]], shape=(2, 1), dtype=float64)
# ****
# For epoch  939 , the weights =  tf.Tensor(
# [[-0.01004178]
#  [ 0.4885673 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  940 , the weights =  tf.Tensor(
# [[-0.00970412]
#  [ 0.48890497]], shape=(2, 1), dtype=float64)
# ****
# For epoch  941 , the weights =  tf.Tensor(
# [[-0.00937568]
#  [ 0.4892334 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  942 , the weights =  tf.Tensor(
# [[-0.00936543]
#  [ 0.48924366]], shape=(2, 1), dtype=float64)
# ****
# For epoch  943 , the weights =  tf.Tensor(
# [[-0.00919572]
#  [ 0.48941337]], shape=(2, 1), dtype=float64)
# ****
# For epoch  944 , the weights =  tf.Tensor(
# [[-0.00899219]
#  [ 0.4896169 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  945 , the weights =  tf.Tensor(
# [[-0.00850794]
#  [ 0.49010115]], shape=(2, 1), dtype=float64)
# ****
# For epoch  946 , the weights =  tf.Tensor(
# [[-0.00818859]
#  [ 0.49042049]], shape=(2, 1), dtype=float64)
# ****
# For epoch  947 , the weights =  tf.Tensor(
# [[-0.00778259]
#  [ 0.4908265 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  948 , the weights =  tf.Tensor(
# [[-0.00769356]
#  [ 0.49091552]], shape=(2, 1), dtype=float64)
# ****
# For epoch  949 , the weights =  tf.Tensor(
# [[-0.00740184]
#  [ 0.49120725]], shape=(2, 1), dtype=float64)
# ****
# For epoch  950 , the weights =  tf.Tensor(
# [[-0.00731643]
#  [ 0.49129266]], shape=(2, 1), dtype=float64)
# ****
# For epoch  951 , the weights =  tf.Tensor(
# [[-0.00695246]
#  [ 0.49165663]], shape=(2, 1), dtype=float64)
# ****
# For epoch  952 , the weights =  tf.Tensor(
# [[-0.00710693]
#  [ 0.49150216]], shape=(2, 1), dtype=float64)
# ****
# For epoch  953 , the weights =  tf.Tensor(
# [[-0.00722418]
#  [ 0.49138491]], shape=(2, 1), dtype=float64)
# ****
# For epoch  954 , the weights =  tf.Tensor(
# [[-0.00681743]
#  [ 0.49179166]], shape=(2, 1), dtype=float64)
# ****
# For epoch  955 , the weights =  tf.Tensor(
# [[-0.0065651 ]
#  [ 0.49204399]], shape=(2, 1), dtype=float64)
# ****
# For epoch  956 , the weights =  tf.Tensor(
# [[-0.00632247]
#  [ 0.49228662]], shape=(2, 1), dtype=float64)
# ****
# For epoch  957 , the weights =  tf.Tensor(
# [[-0.00610903]
#  [ 0.49250005]], shape=(2, 1), dtype=float64)
# ****
# For epoch  958 , the weights =  tf.Tensor(
# [[-0.00559583]
#  [ 0.49301326]], shape=(2, 1), dtype=float64)
# ****
# For epoch  959 , the weights =  tf.Tensor(
# [[-0.00502398]
#  [ 0.49358511]], shape=(2, 1), dtype=float64)
# ****
# For epoch  960 , the weights =  tf.Tensor(
# [[-0.00506363]
#  [ 0.49354545]], shape=(2, 1), dtype=float64)
# ****
# For epoch  961 , the weights =  tf.Tensor(
# [[-0.00466546]
#  [ 0.49394362]], shape=(2, 1), dtype=float64)
# ****
# For epoch  962 , the weights =  tf.Tensor(
# [[-0.00418547]
#  [ 0.49442361]], shape=(2, 1), dtype=float64)
# ****
# For epoch  963 , the weights =  tf.Tensor(
# [[-0.00402968]
#  [ 0.49457941]], shape=(2, 1), dtype=float64)
# ****
# For epoch  964 , the weights =  tf.Tensor(
# [[-0.00421254]
#  [ 0.49439655]], shape=(2, 1), dtype=float64)
# ****
# For epoch  965 , the weights =  tf.Tensor(
# [[-0.00368838]
#  [ 0.49492071]], shape=(2, 1), dtype=float64)
# ****
# For epoch  966 , the weights =  tf.Tensor(
# [[-0.00365005]
#  [ 0.49495904]], shape=(2, 1), dtype=float64)
# ****
# For epoch  967 , the weights =  tf.Tensor(
# [[-0.00331331]
#  [ 0.49529577]], shape=(2, 1), dtype=float64)
# ****
# For epoch  968 , the weights =  tf.Tensor(
# [[-0.00289223]
#  [ 0.49571686]], shape=(2, 1), dtype=float64)
# ****
# For epoch  969 , the weights =  tf.Tensor(
# [[-0.00284081]
#  [ 0.49576828]], shape=(2, 1), dtype=float64)
# ****
# For epoch  970 , the weights =  tf.Tensor(
# [[-0.00329529]
#  [ 0.49531379]], shape=(2, 1), dtype=float64)
# ****
# For epoch  971 , the weights =  tf.Tensor(
# [[-0.00302752]
#  [ 0.49558156]], shape=(2, 1), dtype=float64)
# ****
# For epoch  972 , the weights =  tf.Tensor(
# [[-0.0029799 ]
#  [ 0.49562919]], shape=(2, 1), dtype=float64)
# ****
# For epoch  973 , the weights =  tf.Tensor(
# [[-0.00251514]
#  [ 0.49609394]], shape=(2, 1), dtype=float64)
# ****
# For epoch  974 , the weights =  tf.Tensor(
# [[-0.00264748]
#  [ 0.4959616 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  975 , the weights =  tf.Tensor(
# [[-0.00261836]
#  [ 0.49599073]], shape=(2, 1), dtype=float64)
# ****
# For epoch  976 , the weights =  tf.Tensor(
# [[-0.00262763]
#  [ 0.49598146]], shape=(2, 1), dtype=float64)
# ****
# For epoch  977 , the weights =  tf.Tensor(
# [[-0.00245874]
#  [ 0.49615035]], shape=(2, 1), dtype=float64)
# ****
# For epoch  978 , the weights =  tf.Tensor(
# [[-0.0023232 ]
#  [ 0.49628588]], shape=(2, 1), dtype=float64)
# ****
# For epoch  979 , the weights =  tf.Tensor(
# [[-0.00239889]
#  [ 0.4962102 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  980 , the weights =  tf.Tensor(
# [[-0.00240128]
#  [ 0.4962078 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  981 , the weights =  tf.Tensor(
# [[-0.00216528]
#  [ 0.4964438 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  982 , the weights =  tf.Tensor(
# [[-0.00233428]
#  [ 0.4962748 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  983 , the weights =  tf.Tensor(
# [[-0.00250366]
#  [ 0.49610542]], shape=(2, 1), dtype=float64)
# ****
# For epoch  984 , the weights =  tf.Tensor(
# [[-0.00221384]
#  [ 0.49639525]], shape=(2, 1), dtype=float64)
# ****
# For epoch  985 , the weights =  tf.Tensor(
# [[-0.00210608]
#  [ 0.49650301]], shape=(2, 1), dtype=float64)
# ****
# For epoch  986 , the weights =  tf.Tensor(
# [[-0.00208381]
#  [ 0.49652528]], shape=(2, 1), dtype=float64)
# ****
# For epoch  987 , the weights =  tf.Tensor(
# [[-0.00244068]
#  [ 0.49616841]], shape=(2, 1), dtype=float64)
# ****
# For epoch  988 , the weights =  tf.Tensor(
# [[-0.00213994]
#  [ 0.49646915]], shape=(2, 1), dtype=float64)
# ****
# For epoch  989 , the weights =  tf.Tensor(
# [[-0.00221201]
#  [ 0.49639708]], shape=(2, 1), dtype=float64)
# ****
# For epoch  990 , the weights =  tf.Tensor(
# [[-0.00156938]
#  [ 0.4970397 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  991 , the weights =  tf.Tensor(
# [[-0.0012752 ]
#  [ 0.49733388]], shape=(2, 1), dtype=float64)
# ****
# For epoch  992 , the weights =  tf.Tensor(
# [[-0.00081666]
#  [ 0.49779242]], shape=(2, 1), dtype=float64)
# ****
# For epoch  993 , the weights =  tf.Tensor(
# [[-0.00059792]
#  [ 0.49801116]], shape=(2, 1), dtype=float64)
# ****
# For epoch  994 , the weights =  tf.Tensor(
# [[-2.97191863e-04]
#  [ 4.98311894e-01]], shape=(2, 1), dtype=float64)
# ****
# For epoch  995 , the weights =  tf.Tensor(
# [[-0.00064021]
#  [ 0.49796887]], shape=(2, 1), dtype=float64)
# ****
# For epoch  996 , the weights =  tf.Tensor(
# [[-4.91489720e-04]
#  [ 4.98117597e-01]], shape=(2, 1), dtype=float64)
# ****
# For epoch  997 , the weights =  tf.Tensor(
# [[-5.62786451e-05]
#  [ 4.98552808e-01]], shape=(2, 1), dtype=float64)
# ****
# For epoch  998 , the weights =  tf.Tensor(
# [[3.10865055e-05]
#  [4.98640173e-01]], shape=(2, 1), dtype=float64)
# ****
# For epoch  999 , the weights =  tf.Tensor(
# [[2.97909175e-04]
#  [4.98906995e-01]], shape=(2, 1), dtype=float64)
# ****
# For epoch  1000 , the weights =  tf.Tensor(
# [[-8.67170700e-05]
#  [ 4.98522369e-01]], shape=(2, 1), dtype=float64)

# %% [markdown]
# Phew! Observed how weights and bias correct themselves on each iteration, and each epoch? It's a long process!

# %% [markdown]
# Let's observe how the loss dropped over a period of time- on the y-axis we have the loss (mean squared error), and epochs on the x-axis

# %%
import matplotlib.pyplot as plt
time_axis = range(1,len(err)+1)
plt.plot(  time_axis, err)
plt.show()

# %% [markdown]
# After this, we can locate the point on the graph with minimum y (because this is an error). That's the point at which we can then retrain the model.

# %% [markdown]
# **Conclusion**

# %% [markdown]
# In this module we achieved the following:
#
#
#
# *   Revised the model training process
# *   Simulated the model training
# *   Observed inbuilt TensorFlow functions
# *   Initialized weights and bias
# *   Observed their updates over iterations and epochs
# *   Calculated and plotted the errors over epochs
